# %%
from langchain_anthropic import ChatAnthropic
from dotenv import load_dotenv
load_dotenv()

import os

if os.getenv("ANTHROPIC_API_KEY") is None:
    raise ValueError("ANTROPIC_API_KEY environment variable not set")

# %%
llm = ChatAnthropic(model="claude-haiku-4-5-20251001")
response = llm.invoke("Give me the code to create a pandas dataframe with 3 columns and 5 rows")
response.content
# Out:
# "# Basic DataFrame Creation\n\nHere are a few ways to create a pandas DataFrame with 3 columns and 5 rows:\n\n## Method 1: Using a Dictionary\n```python\nimport pandas as pd\n\ndf = pd.DataFrame({\n    'Column1': [1, 2, 3, 4, 5],\n    'Column2': ['a', 'b', 'c', 'd', 'e'],\n    'Column3': [10.5, 20.3, 15.7, 25.1, 30.9]\n})\n\nprint(df)\n```\n\n## Method 2: Using a List of Lists\n```python\nimport pandas as pd\n\ndata = [\n    [1, 'a', 10.5],\n    [2, 'b', 20.3],\n    [3, 'c', 15.7],\n    [4, 'd', 25.1],\n    [5, 'e', 30.9]\n]\n\ndf = pd.DataFrame(data, columns=['Column1', 'Column2', 'Column3'])\n\nprint(df)\n```\n\n## Method 3: Using NumPy\n```python\nimport pandas as pd\nimport numpy as np\n\ndf = pd.DataFrame(np.random.rand(5, 3), columns=['Column1', 'Column2', 'Column3'])\n\nprint(df)\n```\n\n## Output (Method 1)\n```\n   Column1 Column2  Column3\n0        1       a     10.5\n1        2       b     20.3\n2        3       c     15.7\n3        4       d     25.1\n4        5       e  
# ...

# %%
llm = ChatAnthropic(model="claude-haiku-4-5-20251001")
response = llm.invoke("create a file that contains the code to create a pandas dataframe with 3 columns and 5 rows")
response.content
# Out:
# "# Here's a Python file that creates a pandas DataFrame with 3 columns and 5 rows:\n\n```python\n# create_dataframe.py\nimport pandas as pd\n\n# Create a DataFrame with 3 columns and 5 rows\ndata = {\n    'Column1': [10, 20, 30, 40, 50],\n    'Column2': ['A', 'B', 'C', 'D', 'E'],\n    'Column3': [1.5, 2.5, 3.5, 4.5, 5.5]\n}\n\ndf = pd.DataFrame(data)\n\n# Display the DataFrame\nprint(df)\n```\n\n**Output:**\n```\n   Column1 Column2  Column3\n0       10       A      1.5\n1       20       B      2.5\n2       30       C      3.5\n3       40       D      4.5\n4       50       E      5.5\n```\n\n**Alternative approach using lists:**\n\n```python\n# create_dataframe_alt.py\nimport pandas as pd\n\n# Create a DataFrame using lists\ndf = pd.DataFrame(\n    [[10, 'A', 1.5],\n     [20, 'B', 2.5],\n     [30, 'C', 3.5],\n     [40, 'D', 4.5],\n     [50, 'E', 5.5]],\n    columns=['Column1', 'Column2', 'Column3']\n)\n\nprint(df)\n```\n\nBoth approaches create the same DataFrame. Choose whichever sty
# ...
